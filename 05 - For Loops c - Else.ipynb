# %%
#Eg 1 Else in a For loop
for x in range(6):
    print(x)
else:
    print("Finally finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# Finally finished!

# %%
#Eg 2 Nested Loops - print each adjective for each space
adj = ["nebulous", "spiral", "super massive"]
space = ["cloud", "galaxy", "black hole"]

for x in adj:
    for y in space:
        print(x, y)
# Out:
# nebulous cloud
# nebulous galaxy
# nebulous black hole
# spiral cloud
# spiral galaxy
# spiral black hole
# super massive cloud
# super massive galaxy
# super massive black hole

# %%
adj = ["nebulous", "spiral", "super massive"]
space = ["cloud", "galaxy", "black hole"]

for x in adj:
    if x ==
