# %%
#Defining a function
def func1():
    print("ahh")
    print("ahhh2")

# %%
#Calling a function
func1()
# Out:
# ahh
# ahhh2

# %%
def func2(x):
    return 2*x

# %%
a = func2(3)

# %%
print (a)
# Out:
# 6

# %%
b = func2(8.5)

# %%
print (b)
# Out:
# 17.0

# %%
c = func2 (11.25)
print (c)
# Out:
# 22.5

# %% [markdown]
# **Arguments & Returns**

# %%
def func3(x, y):
    return x + y

# %%
v = func3(4, 11)
print (v)
# Out:
# 15

# %%
def func5(x):
    print (x)
    print ("still in this function")
    return 3*x

# %%
f = func5(6)
# Out:
# 6
# still in this function

# %%
print (f)
# Out:
# 18

# %%
#BMI Calculator
name1 = "YK"
ht1 = 2
wt1 = 90

name2 = "YK's Sis"
ht2 = 1.8
wt2 = 70

name3 = "YK's Bro"
ht3 = 2.5
wt3 = 160

# %%
def bmi_calc(name, ht, wt):
    bmi = wt/(ht**2)
    print("bmi: ")
    print(bmi)
    if bmi<25:
        return name + "is not overweight"
    else:
        return name + "is overweight"

# %%
result1 = bmi_calc(name1, ht1, wt1)
print (result1)
# Out:
# bmi:
# 22.5
# YKis not overweight
