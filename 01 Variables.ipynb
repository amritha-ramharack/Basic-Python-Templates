# %%
print("Hello world")
# Out:
# Hello world

# %%
'''multi line
comment'''

# %%
5%2
# Out:
# 1

# %%
quote = "\"Hello everyone"
print(quote)
# Out:
# "Hello everyone

# %%
quote = "Hello everyone."
quote_2 = "How are you?"
print("%s %s %s" % ('Juat wanna say', quote, quote_2))
# Out:
# Juat wanna say Hello everyone. How are you?
