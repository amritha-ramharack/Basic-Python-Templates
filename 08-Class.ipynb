# %% [markdown]
# Create a way to insert a name and age into the person when the class is created.
# **def __init__(self, supply arguments used to make class, supply arguments used to make class):**
#
#  **def say_name(self):
#         print('My name is %s' % self.name)**
#     Define the function using the self keyword.
#     Self is an implicit keyword that references the class
#     def name_of_function(self).

# %%
#Class is a clollection of things that something is and can do.
#Define class
class Person:
    name = None
    age = None 
    def __init__(self, name, age):
    self.name = name
    self.age = age
    def say_name(self):
        print('My name is %s' % self.name)
    #Define the function using the self keyword.
    #Self is an implicit keyword that references the class
    #def name_of_function(self). 
    def say_age(self):
        print('My age is %d' % self.age)
